# %% [markdown]
# Copyright (c) 2019 [Georgina Flesia](georgina.flesia@unc.edu.ar)
#
# http://www.famaf.proed.unc.edu.ar/course/view.php?id=470

# %% [markdown]
# # Python Machine Learning - Minería de datos- Hipótesis

# %% [markdown]
# # Segunda semana

# %%
from IPython.display import Image

# %% [markdown]
# ### En un consultorio oftalmológico la secretaria entrega a cada paciente la siguiente ficha, antes ser atendido, para que sea completada por el profesional:

# %%
Image(filename='./images/Imagen3.png', width=900)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f6b3973f8d73> in <module>
# ----> 1 Image(filename='./images/Imagen3.png', width=900)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1184         self.unconfined = unconfined
#    1185         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1186                 metadata=metadata)
#    1187
#    1188         if self.width is None and self.metadata.get('width', {}):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     613             self.metadata = {}
#     614
# --> 615         self.reload()
#     616         self._check_data()
#     617
#
# ...

# %%
Image(filename='./images/Imagen4.png', width=900)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6ac46d04e6b2> in <module>
# ----> 1 Image(filename='./images/Imagen4.png', width=900)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1184         self.unconfined = unconfined
#    1185         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1186                 metadata=metadata)
#    1187
#    1188         if self.width is None and self.metadata.get('width', {}):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     613             self.metadata = {}
#     614
# --> 615         self.reload()
#     616         self._check_data()
#     617
#
# ...

# %%
Image(filename='./images/Imagen6.png', width=900)

# %% [markdown]
# ### Problema 1: Elaborar una pregunta adecuada sobre los datos para formular un problema de aprendizaje automatico basado en la recomendacion del contactologo.

# %% [markdown]
# ### Respuesta:
# Concepto: Necesita el paciente prescripción de lentes o no necesita lentes?

# %% [markdown]
# ### Problema 2: Señalar los problemas que tienen las tablas recolectadas en el consultorio para abordar el problema de aprendizaje supervisado.

# %% [markdown]
# ### Respuesta:
# La muestra de datos analizada posee instancias que contienen algunos atributos (como la edad del paciente) que no son utilizados para evaluar si las hipotesis son verdaderas o falsas. Dichos datos podrian omirse a efectos de reducir el espacio de hipotesis a evaluar. Sobre el atributo 'Prescripción' solo se observaron dos posibles valores. No parece claro si son las unicos posibles valores. Es decir pueden haber pacientes que no reciban ninguna de dichas prescripciones?. Se debería considerar 'otras prescripciones' como valores posibles? o tal vez ninguna prescripción.
# En ese caso el espacio de  instancias e hipotesis sería mayor, y el arbol de decición debería considerar esos casos.

# %% [markdown]
# ### Problema 3: A partir de la informacion disponible, elaborar un esquema apropiado para disponer los datos en una tabla util para mineria. Identificar las caracteristicas (variables) y su tipo de datos y declarar cual es la clase y sus valores para el problema de clasificacion.

# %% [markdown]
# <h2>Caracteristicas de las variables observadas</h2>
# <table  style="width:80%" align="left">
#     <caption align="bottom">Posibles clasificaciones  para las recomencaciones realizadas por el contactólogo: nada, lentes duras, lentes blandas </caption>
#     <thead>
#         <tr> <th>Atributo/Caracteristica</th> <th>Rango de valores</th> <th> Tipo de datos</th> </tr>
#     </thead>
#     <tbody>
#         <tr> <td align="left">Edad</td> <td>10-100 años</td> <td>Integer</td> </tr>
#         <tr> <td align="left">Prescripción</td> <td>miopía, hipertrometía</td> <td>String</td> </tr>
#         <tr> <td align="left">Astigmatismo</td> <td>si, no</td> <td>Boolean</td> </tr>
#         <tr> <td align="left">Lagrimeo</td> <td>reducido, normal</td> <td>string</td> </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Problema 4: Calcular el numero total de instancias posibles, suponiendo que la posible edad de un paciente esta en el intervalo que incluye los valores 10 y 100.

# %% [markdown]
# ### Respuesta:
# En total existen 90 * 2 * 2 * 2 = 90*8 = 720 instancias posibles

# %% [markdown]
# ### Problema 5: Construir la tabla de mineria con los ejemplos dados a partir del esquema formulado, dejando la clase en la ultima columna.

# %% [markdown]
# <h2>Muestras de entrenamiento en tabla de minería de datos</h2>
# <table  style="width:80%" align="left">
#     <caption align="bottom"></caption>
#     <thead>
#         <tr>
#             <th>Paciente</th><th>Edad</th><th>Prescripción</th><th>Astigmatismo</th><th>Lagrimeo</th><th> Clase</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr> <td align="left">1</td> <td>22</td><td>miopia</td><td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">2</td> <td>71</td><td>miopia</td><td>si</td><td>normal<td>duras</tr>
#         <tr> <td align="left">3</td> <td>41</td><td>hipermetropía</td> <td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">4</td> <td>32</td><td>miopia</td><td>si</td><td>normal</td> <td>duras</td></tr>
#         <tr> <td align="left">5</td> <td>68</td><td>hipermetropía</td><td>si</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">6</td> <td>72</td><td>miopia</td><td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">7</td> <td>62</td><td>hipermetropía</td><td>si</td><td>normal</td> <td>nada</td></tr>
#         <tr> <td align="left">8</td> <td>42</td><td>miopia</td><td>si</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">9</td> <td>38</td><td>miopia</td><td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">10</td> <td>43</td><td>miopia</td><td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">11</td> <td>28</td><td>hipermetropía</td><td>si</td><td>normal</td> <td>nada</td></tr>
#         <tr> <td align="left">12</td> <td>37</td><td>miopia</td><td>si</td><td>normal</td> <td>duras</td></tr>
#         <tr> <td align="left">13</td> <td>45</td><td>hipermetropía</td><td>si</td><td>normal</td> <td>nada</td></tr>
#         <tr> <td align="left">14</td> <td>37</td><td>hipermetropía</td><td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">15</td> <td>68</td><td>hipermetropía</td><td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">16</td> <td>18</td><td>miopia</td><td>si</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">17</td> <td>51</td><td>miopia</td><td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">18</td> <td>15</td><td>hipermetropía</td><td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">19</td> <td>63</td><td>miopia</td><td>si</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">20</td> <td>30</td><td>miopia</td> <td>no</td><td>normal</td> <td>blandas</td></tr>
#         <tr> <td align="left">21</td> <td>74</td><td>hipermetropía</td><td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">22</td> <td>44</td><td>hipermetropía</td><td>si</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">23</td> <td>15</td><td>hipermetropía</td><td>no</td><td>reducido</td> <td>nada</td></tr>
#         <tr> <td align="left">24</td> <td>17</td><td>hipermetropía</td><td>si<td>reducido</td> <td>nada</td></tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Problema 6: Determinar a partir de los datos si las siguientes hipotesis son verdaderas o falsas:
# Si el lagrimeo es reducido entonces la recomendacion es nada (es decir, no usar lentes de contacto).
# Si la prescripcion es hipermetropia, no tiene astigmatismo y el lagrimeo es normal entonces la recomendacion es lentes duras.

# %% [markdown]
# ### Respuesta:
# <table  style="width:40%" align="left">
#     <thead>
#     </thead>
#     <tbody>
#         <tr> <td width="40">Hipotesis 1</td> <td width="160">Si el lagrimeo es reducido entonces no se recomiendan lentes</td> <td width="20">V</td> </tr>
#         <tr> <td align="left">Hipitesis 2</td> <td>Si la prescripcion es hipermetromia, no tiene astigmatismo y el lagrimeo es normal , se recomiendan lentes duras</td> <td>F</td> </tr>
#      </tbody>
# </table>

# %% [markdown]
# ### Problema 7: Elaborar las hipotesis especificas maximales en el aprendizaje de los conceptos: prescripcion de lentes duras y prescripcion de lentes blandas. Ayuda: Reconocer previamente las variables irrelevantes para ambos problemas.

# %% [markdown]
# ### Respuesta:
# <table  style="width:40%" align="left">
#     <thead>
#     </thead>
#     <tbody>
#         <tr> <td width="100">Hipotesis maximal para lentes blandas</td> <td width="80">(?, no, normal)</td> </tr>
#         <tr> <td align="left">Hipotesis maximal para lentes duras</td> <td>(miopia, si, normal)</td>  </tr>
#      </tbody>
# </table>

# %% [markdown]
# ### Problema 8: Utilizando las hipotesis especıficas elaboradas, construir un arbol de decision utilizando en cada nodo la sentencia if sobre los valores una caracterıstica para reproducir el criterio de clasificacion empleado en el consultorio oftalmologico.
# Ayuda: Las decisiones en cada nodo sobre los valores de las caracteristicas son todas binarias y no se repiten caracteristicas una vez usadas. La construccion de este arbol determina una jerarquia de las caracteristicas en cuanto su importancia en la determinacion de la clase.

# %% [markdown]
# <br>
# <br>

# %%
from IPython.display import Image; Image(filename='./images/tree.png', width=900)

# %% [markdown]
# El nodo **Se prescribio hipermetropía?** podría no haberse dibujado, pero preferí dejarlo para notar que tal vez son necesarios mas datos para completar una opción que contemple que se pueden haber realizado otro tipo de prescripciones o ninguna prescripción.
